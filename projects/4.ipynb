# %%
import pandas as pd
import numpy as ny
import seaborn as sns

# %%
data = pd.read_csv("iris_csv.csv")

# %%
data.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.sample(10)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth            class
# 81           5.5         2.4          3.7         1.0  Iris-versicolor
# 26           5.0         3.4          1.6         0.4      Iris-setosa
# 91           6.1         3.0          4.6         1.4  Iris-versicolor
# 78           6.0         2.9          4.5         1.5  Iris-versicolor
# 43           5.0         3.5          1.6         0.6      Iris-setosa
# 122          7.7         2.8          6.7         2.0   Iris-virginica
# 130          7.4         2.8          6.1         1.9   Iris-virginica
# 61           5.9         3.0          4.2         1.5  Iris-versicolor
# 109          7.2         3.6          6.1         2.5   Iris-virginica
# 48           5.3         3.7          1.5         0.2      Iris-setosa

# %%
data.columns
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
print(data)
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(data[10:21])
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# 13          4.3         3.0          1.1         0.1  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa
# 17          5.1         3.5          1.4         0.3  Iris-setosa
# 18          5.7         3.8          1.7         0.3  Iris-setosa
# 19          5.1         3.8          1.5         0.3  Iris-setosa
# 20          5.4         3.4          1.7         0.2  Iris-setosa
#     sepallength  sepalwidth  petallength  petalwidth        class
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# ...

# %% [markdown]
# # create a new category from existing data

# %%
specific_data=data["class"]
print(specific_data.head(10))
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# 5    Iris-setosa
# 6    Iris-setosa
# 7    Iris-setosa
# 8    Iris-setosa
# 9    Iris-setosa
# Name: class, dtype: object

# %%
data.iloc[5]
data.loc[data["class"] == "Iris-setosa"]
# Out:
#     sepallength  sepalwidth  petallength  petalwidth        class
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.2          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.4         0.2  Iris-setosa
# 9           4.9         3.1          1.5         0.1  Iris-setosa
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# ...

# %%
data["class"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
sum_data = data["sepallength"].sum()
mean_data = data["sepalwidth"].mean()
median_data = data["petallength"].median()
  
print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 3.0540000000000003
# Median: 4.35

# %%
min_data=data["sepallength"].min()
max_data=data["sepalwidth"].max()
  
print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 4.4

# %%
cols = data.columns
print(cols)
cols = cols[1:5]
data1 = data[cols]
data["total_values"]=data1[cols].sum(axis=1)
# Out:
# Index(['sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class'], dtype='object')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16712\2414568064.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data["total_values"]=data1[cols].sum(axis=1)

# %% [markdown]
# # recode variables

# %%
newcols={
"sepallength":"SepalLengthCm",
"sepalwidth":"SepalWidthCm"}
  
data.rename(columns=newcols,inplace=True)
  
print(data.head())
# Out:
#    SepalLengthCm  SepalWidthCm  petallength  petalwidth        class  \
# 0            5.1           3.5          1.4         0.2  Iris-setosa
# 1            4.9           3.0          1.4         0.2  Iris-setosa
# 2            4.7           3.2          1.3         0.2  Iris-setosa
# 3            4.6           3.1          1.5         0.2  Iris-setosa
# 4            5.0           3.6          1.4         0.2  Iris-setosa
#
#    total_values
# 0           5.1
# 1           4.6
# 2           4.7
# 3           4.8
# 4           5.2

# %%
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_59051">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59051_level0_col0" class="col_heading level0 col0" >SepalLengthCm</th>
#       <th id="T_59051_level0_col1" class="col_heading level0 col1" >SepalWidthCm</th>
#       <th id="T_59051_level0_col2" class="col_heading level0 col2" >petallength</th>
#       <th id="T_59051_level0_col3" class="col_heading level0 col3" >petalwidth</th>
#       <th id="T_59051_level0_col4" class="col_heading level0 col4" >class</th>
#       <th id="T_59051_level0_col5" class="col_heading level0 col5" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59051_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59051_row0_col0" class="data row0 col0" >5.100000</td>
#       <td id="T_59051_row0_col1" class="data row0 col1" >3.500000</td>
#       <td id="T_59051_row0_col2" class="data row0 col2" >1.400000</td>
# ...

# %%
data.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  petallength  petalwidth  class  total_values
# 0            False         False        False       False  False         False
# 1            False         False        False       False  False         False
# 2            False         False        False       False  False         False
# 3            False         False        False       False  False         False
# 4            False         False        False       False  False         False
# ..             ...           ...          ...         ...    ...           ...
# 145          False         False        False       False  False         False
# 146          False         False        False       False  False         False
# 147          False         False        False       False  False         False
# 148          False         False        False       False  False         False
# 149          False         False        False       False  False         False
#
# [150 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# petallength      0
# petalwidth       0
# class            0
# total_values     0
# dtype: int64

# %%
import seaborn as sns
  
iris = sns.load_dataset("iris")
sns.heatmap(iris.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(), annot = True )
# Out:
# <AxesSubplot:>

# %%
data.corr(method='pearson')
# Out:
#                SepalLengthCm  SepalWidthCm  petallength  petalwidth  \
# SepalLengthCm       1.000000     -0.109369     0.871754    0.817954
# SepalWidthCm       -0.109369      1.000000    -0.420516   -0.356544
# petallength         0.871754     -0.420516     1.000000    0.962757
# petalwidth          0.817954     -0.356544     0.962757    1.000000
# total_values        0.893970     -0.245361     0.979301    0.975264
#
#                total_values
# SepalLengthCm      0.893970
# SepalWidthCm      -0.245361
# petallength        0.979301
# petalwidth         0.975264
# total_values       1.000000

# %%
g = sns.pairplot(data,hue="class")

# %% [markdown]
# # Inserted a new command as Boxplot

# %%
data.boxplot(fontsize='small',figsize=(16,16))
# Out:
# <AxesSubplot:>
